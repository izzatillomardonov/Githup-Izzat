# %% [markdown]
# <a href="https://colab.research.google.com/github/izzatillomardonov/Githup-Izzat/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('team_data.csv')
df
# Out:
#               team  players_used  avg_age  possession  games  games_starts  \
# 0        Argentina            21     28.5        61.6      5            55
# 1        Australia            20     28.7        37.8      4            44
# 2          Belgium            20     30.6        57.0      3            33
# 3           Brazil            26     28.4        56.2      5            55
# 4         Cameroon            22     28.0        41.7      3            33
# 5           Canada            19     28.2        52.0      3            33
# 6       Costa Rica            22     30.6        31.3      3            33
# 7          Croatia            18     29.3        54.0      5            55
# 8          Denmark            20     27.5        60.0      3            33
# 9          Ecuador            18     25.8        53.3      3            33
# 10         England            20     27.0        62.8      5            55
# ...

# %%
df=pd.read_csv('team_data.csv',index_col='team')
df
# Out:
#                 players_used  avg_age  possession  games  games_starts  \
# team
# Argentina                 21     28.5        61.6      5            55
# Australia                 20     28.7        37.8      4            44
# Belgium                   20     30.6        57.0      3            33
# Brazil                    26     28.4        56.2      5            55
# Cameroon                  22     28.0        41.7      3            33
# Canada                    19     28.2        52.0      3            33
# Costa Rica                22     30.6        31.3      3            33
# Croatia                   18     29.3        54.0      5            55
# Denmark                   20     27.5        60.0      3            33
# Ecuador                   18     25.8        53.3      3            33
# England                   20     27.0        62.8      5            55
# France                    24     27.3        54.8      5            55
# ...

# %%
len(df.columns)
# Out:
# 188

# %%
len(df.index)
# Out:
# 32

# %%
df=pd.read_csv("team_data.csv",index_col=0)
df.head()
# Out:
#            players_used  avg_age  possession  games  games_starts  minutes  \
# team
# Argentina            21     28.5        61.6      5            55      480
# Australia            20     28.7        37.8      4            44      360
# Belgium              20     30.6        57.0      3            33      270
# Brazil               26     28.4        56.2      5            55      480
# Cameroon             22     28.0        41.7      3            33      270
#
#            minutes_90s  goals  assists  goals_pens  ...  fouls  fouled  \
# team                                                ...
# Argentina          5.3      9        6           7  ...     59      89
# Australia          4.0      3        3           3  ...     52      34
# Belgium            3.0      1        1           1  ...     30      35
# Brazil             5.3      8        6           7  ...     63      74
# Cameroon           3.0      4        4           4  ...     32      38
#
# ...

# %%
len(df.index)
# Out:
# 32

# %%
x=df.columns
x
# Out:
# Index(['players_used', 'avg_age', 'possession', 'games', 'games_starts',
#        'minutes', 'minutes_90s', 'goals', 'assists', 'goals_pens',
#        ...
#        'fouls', 'fouled', 'offsides', 'pens_won', 'pens_conceded', 'own_goals',
#        'ball_recoveries', 'aerials_won', 'aerials_lost', 'aerials_won_pct'],
#       dtype='object', length=188)

# %%
x=np.sort(x)
x
# Out:
# array(['aerials_lost', 'aerials_won', 'aerials_won_pct', 'assisted_shots',
#        'assists', 'assists_per90', 'average_shot_distance', 'avg_age',
#        'ball_recoveries', 'blocked_passes', 'blocked_shots', 'blocks',
#        'cards_red', 'cards_yellow', 'cards_yellow_red', 'clearances',
#        'corner_kicks', 'corner_kicks_in', 'corner_kicks_out',
#        'corner_kicks_straight', 'crosses', 'crosses_into_penalty_area',
#        'dispossessed', 'dribble_tackles', 'dribble_tackles_pct',
#        'dribbled_past', 'dribbles', 'dribbles_completed',
#        'dribbles_completed_pct', 'dribbles_vs', 'errors', 'fouled',
#        'fouls', 'games', 'games_complete', 'games_starts', 'games_subs',
#        'gca', 'gca_defense', 'gca_dribbles', 'gca_fouled',
#        'gca_passes_dead', 'gca_passes_live', 'gca_per90', 'gca_shots',
#        'gk_avg_distance_def_actions', 'gk_clean_sheets',
#        'gk_clean_sheets_pct', 'gk_corner_kick_goals_against',
# ...

# %%
len(x)
x=["aerials_yo'qotilgan", 'aerials_won', 'aerials_won_pct', "yordamli_o'qlar",
       'assist', 'assists_per 90', "o'rtacha_zarba_masofa", "o'rtacha_yosh",
       "to'pni_tiklashlar", 'bloklangan_paslar', 'bloklangan_otishmalar', 'bloklar',
       'kartalar_qizil', 'kartalar_sariq', 'kartalar_sariq_qizil', "bo'sh joylar",
       "burchak_to'plari", "burchak_to'plari", 'burchak_tepkilari',
       "to'g'ridan-to'g'ri burchakli zarbalar", "to'p uzatishlar", "jarima_maydoniga_o'tishlar",
       'egasiz', 'dribble_tackles', 'dribble_tackles_pct',
       'dribbled_past', 'dribbles', 'dribbles_completed',
       'dribbles_completed_pct', 'dribbles_vs', 'xato', 'pouled',
       'qoidabuzarliklar', "o'yinlar", "o'yinlar_tugallangan", "o'yinlar_boshlanadi", "o'yinlar_obunalari",
       'gca', 'gca_defense', 'gca_dribbles', 'gca_fouled',
       'gca_passes_dead', 'gca_passes_live', 'gca_per90', 'gca_shots',
       'gk_avg_distance_def_actions', 'gk_clean_sheets',
       'gk_clean_sheets_pct', 'gk_corner_kick_goals_gainst',
       'gk_crosses', 'gk_crosses_stopped', 'gk_crosses_stopped_pct',
       'gk_def_actions_outside_pen_area',
       'gk_def_actions_outside_pen_area_per90',
       'gk_free_kick_goals_gainst', 'gk_games', 'gk_games_starts',
       'gk_goal_kick_length_avg', 'gk_goal_kicks', 'gk_goals_gainst',
       'gk_goals_gainst_per90', 'gk_losses', 'gk_minutes',
       'gk_goals_gainst', 'gk_passes',
       'gk_passes_completed_launched', 'gk_passes_launched',
       'gk_passes_length_avg', 'gk_passes_pct_launched',
       'gk_passes_throws', 'gk_pct_goal_kicks_launched',
       'gk_pct_passes_launched', 'gk_pens_allowed', 'gk_pens_att',
       'gk_pens_missed', 'gk_pens_save_pct', 'gk_pens_saqed',
       'gk_psnpxg_per_shot_on_target_gainst', 'gk_psxg', 'gk_psxg_net',
       'gk_psxg_net_per90', 'gk_save_pct', 'gk_saves',
       'gk_shots_on_target_ainst', 'gk_ties', 'gk_wins', 'gollar',
       'gollar_yordamchi_qalamlar_har 90', 'gol_assists_har90', 'gol_qalamlar',
       'goals_pens_har 90', 'gols_for 90', 'gols_har bir 90',
       "maqsaddagi_bosh_otish_gollari", "to'siqlar", "daqiqalar",
       'daqiqa_90s', 'daqiqa_pct', "har_o'yinga_daqiqa",
       'boshlash_boshiga_daqiqa', 'har_sub_daqiqa', "noto'g'ri boshqarishlar", 'npxg',
       'npxg_net', 'npxg_per90', 'npxg_per_shot', 'npxg_xg_assist',
       'npxg_xg_assist_per90', 'offsaydlar', 'goals_gainst',
       'gollar_uchun', 'on_xg_ga qarshi', 'on_xg_for', "o'z_gollari",
       "o'tish_xa", "o'tish", "o'tish_bloklangan", "o'tish_tugallangan",
       "o'tish_tugallangan_uzoq", "o'tish_tugallangan_medium",
       'bajarildi_qisqa', "o'lik_pas", "erkin_toplarni_pas",
       "uchinchi_finalga_o'tadi", "jarima_maydoniga_o'tadi",
       "jonli_o'tadi", "uzoq_o'tadi", "o'rta_o'tadi", "o'yindan_o'tadi",
       'passes_pct', 'passes_pct_long', 'passes_pct_medium',
       'passes_pct_short', 'progressive_distance',
       "o'tadi_qabul", "o'tadi_qisqa", "o'tish_ko'chma",
       "jami_masofadan_o'tadi", 'pens_att', 'qalamlar_talab qilingan', 'qalamlar_yasalgan',
       'pens_won', "ishlatilgan_o'yinchilar", 'plus_minus', 'plus_minus_per90',
       "har_o'yin_ballari", "egalik qilish", 'progressiv_paslar',
       'progressive_passes_received', 'sca', 'sca_defense',
       'sca_dribbles', 'sca_fouled', 'sca_passes_dead', 'sca_passes_live',
       'sca_per90', 'sca_shots', 'shots', 'shots_free_kicks',
       "nishon_to'g'risida_otishlar", "n'on_ko'p_ko'rsatkichlar", "nishon_to'g'rida_otishlar",
       'shots_per90', 'tackles', 'tackles_att_3rd', 'tackles_def_3rd',
       "tackles_to'siqlar", 'tackles_mid_3rd', 'tackles_won',
       "to'plar_orqali", 'otish_otish', 'tegishlar', 'tegishlar_3rd',
       'touches_att_pen_area', 'touches_def_3rd', 'touches_def_pen_area',
       'touches_live_ball', 'touches_mid_3rd', 'foydalanishsiz_obunalar', 'xg',
       'xg_assist', 'xg_assist_net', 'xg_assist_per90', 'xg_net',
       'xg_per90', 'xg_plus_minus', 'xg_plus_minus_per90',
       'xg_xg_assist_per90']

# %%
df.columns=x
df
# Out:
#                 aerials_yo'qotilgan  aerials_won  aerials_won_pct  \
# team
# Argentina                        21         28.5             61.6
# Australia                        20         28.7             37.8
# Belgium                          20         30.6             57.0
# Brazil                           26         28.4             56.2
# Cameroon                         22         28.0             41.7
# Canada                           19         28.2             52.0
# Costa Rica                       22         30.6             31.3
# Croatia                          18         29.3             54.0
# Denmark                          20         27.5             60.0
# Ecuador                          18         25.8             53.3
# England                          20         27.0             62.8
# France                           24         27.3             54.8
# Germany                          20         28.1             59.3
# ...

# %%
df2 = pd.read_csv("group_stats (1).csv") 
df2.head(5)
# Out:
#    Unnamed: 0  group  rank         team  matches_played  wins  draws  losses  \
# 0           0      1     1  Netherlands               3     2      1       0
# 1           1      1     2      Senegal               3     2      0       1
# 2           2      1     3      Ecuador               3     1      1       1
# 3           3      1     4        Qatar               3     0      0       3
# 4           4      2     1      England               3     2      1       0
#
#    goals_scored  goals_against  goal_difference  points  expected_goal_scored  \
# 0             5              1                4       7                   2.4
# 1             5              4                1       6                   3.8
# 2             4              3                1       4                   3.7
# 3             1              7               -6       0                   1.4
# 4             9              2                7       7                   5.2
#
# ...

# %%
df3 = pd.read_excel("130.xlsx") 
df3.head()
# Out:
#    No1                                    FIO Tavsiyanomasi   Bahosi  \
# 0    1  Eshmamatov Faxriddin Xayriddin o'g'li       Kantirak       4
# 1    2      Narimonov Shahboz Bobosher o'g'li       Kantirak       4
# 2    3         Sayfiyeva Muattar Alisher qizi       Kantirak       4
# 3    4    Tolliboyev Arslonbek Bolibek o'g'li          Grant       5
# 4    5         Imomov Imomali Anvarjon o'g'li          Grant       4
#
#        Yashash joyi  Ball
# 0  Jizzax viloyati     95
# 1  Jizzax viloyati    130
# 2  Jizzax viloyati    135
# 3  Jizzax viloyati    180
# 4   Xorazm viloyati   156

# %%
df3.sort_index(axis=1)
df3.head()
# Out:
#    No1                                    FIO Tavsiyanomasi   Bahosi  \
# 0    1  Eshmamatov Faxriddin Xayriddin o'g'li       Kantirak       4
# 1    2      Narimonov Shahboz Bobosher o'g'li       Kantirak       4
# 2    3         Sayfiyeva Muattar Alisher qizi       Kantirak       4
# 3    4    Tolliboyev Arslonbek Bolibek o'g'li          Grant       5
# 4    5         Imomov Imomali Anvarjon o'g'li          Grant       4
#
#        Yashash joyi  Ball
# 0  Jizzax viloyati     95
# 1  Jizzax viloyati    130
# 2  Jizzax viloyati    135
# 3  Jizzax viloyati    180
# 4   Xorazm viloyati   156

# %%
df3 = df3.sort_values('No1')
df3.head()
# Out:
#    No1                                    FIO Tavsiyanomasi   Bahosi  \
# 0    1  Eshmamatov Faxriddin Xayriddin o'g'li       Kantirak       4
# 1    2      Narimonov Shahboz Bobosher o'g'li       Kantirak       4
# 2    3         Sayfiyeva Muattar Alisher qizi       Kantirak       4
# 3    4    Tolliboyev Arslonbek Bolibek o'g'li          Grant       5
# 4    5         Imomov Imomali Anvarjon o'g'li          Grant       4
#
#        Yashash joyi  Ball
# 0  Jizzax viloyati     95
# 1  Jizzax viloyati    130
# 2  Jizzax viloyati    135
# 3  Jizzax viloyati    180
# 4   Xorazm viloyati   156

# %%
k = df3.columns
k
# Out:
# Index(['No1', '                    FIO', 'Tavsiyanomasi ', 'Bahosi',
#        'Yashash joyi', 'Ball'],
#       dtype='object')

# %%
hdf_obj=pd.HDFStore("Ndata.h5")

# %%
hdf_obj.put("data_csv",df2)
hdf_obj.put("data_excel",df3)

# %%
kalit_soz=hdf_obj.keys()
kalit_soz
# Out:
# ['/data_csv', '/data_excel']

# %%
hdf_obj["data_csv"]
# Out:
#     Unnamed: 0  group  rank            team  matches_played  wins  draws  \
# 0            0      1     1     Netherlands               3     2      1
# 1            1      1     2         Senegal               3     2      0
# 2            2      1     3         Ecuador               3     1      1
# 3            3      1     4           Qatar               3     0      0
# 4            4      2     1         England               3     2      1
# 5            5      2     2   United States               3     1      2
# 6            6      2     3         IR Iran               3     1      0
# 7            7      2     4           Wales               3     0      1
# 8            8      3     1       Argentina               3     2      0
# 9            9      3     2          Poland               3     1      1
# 10          10      3     3          Mexico               3     1      1
# 11          11      3     4    Saudi Arabia               3     1      0
# ...

# %%
hdf_obj["data_excel"].head()
# Out:
#    No1                                    FIO Tavsiyanomasi   Bahosi  \
# 0    1  Eshmamatov Faxriddin Xayriddin o'g'li       Kantirak       4
# 1    2      Narimonov Shahboz Bobosher o'g'li       Kantirak       4
# 2    3         Sayfiyeva Muattar Alisher qizi       Kantirak       4
# 3    4    Tolliboyev Arslonbek Bolibek o'g'li          Grant       5
# 4    5         Imomov Imomali Anvarjon o'g'li          Grant       4
#
#        Yashash joyi  Ball
# 0  Jizzax viloyati     95
# 1  Jizzax viloyati    130
# 2  Jizzax viloyati    135
# 3  Jizzax viloyati    180
# 4   Xorazm viloyati   156

# %%
hdf_obj.close() # data yopildi endi funksiya bajarib bo'lmaydi , bajarish uchun open() kk

# %% [markdown]
# 4. Masala.Yuqorida yaratgan .h5 fayl kengaytmali obyektingizni elimentlarini chaqirib oling va DataFrame ning ichidagi takrorlanuvchi va
# keraksiz malumotlarni olib tashlang enga asosiy ustunni tanlab uni indexlariga o’tkazing va qayta saqlang

# %%
HDF1=pd.read_hdf("/content/Ndata.h5",key="data_csv")
HDF1
# Out:
#     Unnamed: 0  group  rank            team  matches_played  wins  draws  \
# 0            0      1     1     Netherlands               3     2      1
# 1            1      1     2         Senegal               3     2      0
# 2            2      1     3         Ecuador               3     1      1
# 3            3      1     4           Qatar               3     0      0
# 4            4      2     1         England               3     2      1
# 5            5      2     2   United States               3     1      2
# 6            6      2     3         IR Iran               3     1      0
# 7            7      2     4           Wales               3     0      1
# 8            8      3     1       Argentina               3     2      0
# 9            9      3     2          Poland               3     1      1
# 10          10      3     3          Mexico               3     1      1
# 11          11      3     4    Saudi Arabia               3     1      0
# ...

# %%
HDF1=pd.read_hdf("/content/Ndata.h5",key="data_csv")
HDF1.index
HDF1.drop('wins', axis=1, inplace=True)
HDF1.drop('goals_against' , axis=1,inplace=True)
HDF1
# Out:
#     Unnamed: 0  group  rank            team  matches_played  draws  losses  \
# 0            0      1     1     Netherlands               3      1       0
# 1            1      1     2         Senegal               3      0       1
# 2            2      1     3         Ecuador               3      1       1
# 3            3      1     4           Qatar               3      0       3
# 4            4      2     1         England               3      1       0
# 5            5      2     2   United States               3      2       0
# 6            6      2     3         IR Iran               3      0       2
# 7            7      2     4           Wales               3      1       2
# 8            8      3     1       Argentina               3      0       1
# 9            9      3     2          Poland               3      1       1
# 10          10      3     3          Mexico               3      1       1
# ...

# %%
HDF2=pd.read_hdf("/content/Ndata.h5", key="data_excel")
HDF2.head(10)
# Out:
#    No1                                    FIO Tavsiyanomasi   Bahosi  \
# 0    1  Eshmamatov Faxriddin Xayriddin o'g'li       Kantirak       4
# 1    2      Narimonov Shahboz Bobosher o'g'li       Kantirak       4
# 2    3         Sayfiyeva Muattar Alisher qizi       Kantirak       4
# 3    4    Tolliboyev Arslonbek Bolibek o'g'li          Grant       5
# 4    5         Imomov Imomali Anvarjon o'g'li          Grant       4
# 5    6  Nazarqosimov Shukurullo Farxod o'g'li          Grant       5
# 6    7      Begimqulov Saidqosim Komil o'g'li          Grant       4
# 7    8           Daminov Jasur Dilshod o'g'li          Grant       5
# 8    9          Rahmatov Ilhom Ihtiyor o'g'li          Grant       5
# 9   10     Abiyorqulov Azamat Asqarjon o'g'li       Kantirak       4
#
#         Yashash joyi  Ball
# 0   Jizzax viloyati     95
# 1   Jizzax viloyati    130
# 2   Jizzax viloyati    135
# 3   Jizzax viloyati    180
# 4    Xorazm viloyati   156
# 5   Jizzax viloyati    120
# ...

# %%
HDF2=pd.read_hdf("/content/Ndata.h5",key="data_excel")
HDF2.index
HDF2.drop('No1', axis=1, inplace=True) # takrorlanucvhi elementni olib tashlash
HDF2
# Out:
#                                         FIO Tavsiyanomasi   Bahosi  \
# 0     Eshmamatov Faxriddin Xayriddin o'g'li       Kantirak       4
# 1         Narimonov Shahboz Bobosher o'g'li       Kantirak       4
# 2            Sayfiyeva Muattar Alisher qizi       Kantirak       4
# 3       Tolliboyev Arslonbek Bolibek o'g'li          Grant       5
# 4            Imomov Imomali Anvarjon o'g'li          Grant       4
# 5     Nazarqosimov Shukurullo Farxod o'g'li          Grant       5
# 6         Begimqulov Saidqosim Komil o'g'li          Grant       4
# 7              Daminov Jasur Dilshod o'g'li          Grant       5
# 8             Rahmatov Ilhom Ihtiyor o'g'li          Grant       5
# 9        Abiyorqulov Azamat Asqarjon o'g'li       Kantirak       4
# 10              Romizov Azamat Oybek o'g'li          Grant       5
# 11             Rashidov Baxrom Zokir o'g'li       Kantirak       4
# 12     Sherbekov Quvonchbek Xolmurot o'g'li       Kantirak       4
# ...
